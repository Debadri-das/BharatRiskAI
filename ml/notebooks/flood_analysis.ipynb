# %% [markdown]
# # BharatRisk AI Flood Analysis
# This placeholder notebook documents the demo dataset. Run `python -m ml.training.train` to generate a deterministic training CSV and Random Forest artifact.
